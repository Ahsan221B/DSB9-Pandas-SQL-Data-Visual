# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/ab-test.csv")
df.head()
# Out:
#        uid        diff    time group
# 0   user_1 -103.333333   after  test
# 1   user_1   -6.000000  before  test
# 2  user_18  -10.000000   after  test
# 3  user_18   -3.500000  before  test
# 4  user_19  -82.333333   after  test

# %%
test_after = after[after['group'] == 'test']['diff']
control_after = after[after['group'] == 'control']['diff']

test_before = before[before['group'] == 'test']['diff']
control_before = before[before['group'] == 'control']['diff']

control_before.head()
# Out:
# 15   -103.0
# 17    -15.5
# 19     -3.0
# 21   -153.0
# 23   -202.0
# Name: diff, dtype: float64

# %%
fig, axes = plt.subplots(1, 2, figsize=(15,8), sharey=True)  
fig.suptitle('Lag before labs deadlines. After and before the Newsfeed', fontsize=15)

axes[0].set_xlabel('[group]')
axes[1].set_xlabel('[group]')

axes[0].set_title('after') 
axes[1].set_title('before ') 

axes[0].grid(True)
axes[1].grid(True)

colors = {'boxes': 'green', 'medians': 'red', 'whiskers': 'red', 'caps': 'red'}

axes[1].boxplot([control_before, test_before], 
                tick_labels=['control', 'test'], 
                patch_artist=True,
                showmeans=True,
                boxprops=dict(facecolor='none', edgecolor='green', linewidth=3),
                medianprops=dict(color=colors['medians'], linewidth=2),
                whiskerprops=dict(color=colors['whiskers']),
                capprops=dict(color=colors['caps']),
                meanprops=dict(marker='^', markerfacecolor='green', markeredgecolor='green')
                )


axes[0].boxplot([control_after, test_after], 
                tick_labels=[ 'control', 'test'], 
                patch_artist=True,
                showmeans=True,
                boxprops=dict(facecolor='none', edgecolor='green', linewidth=3),
                medianprops=dict(color=colors['medians'], linewidth=2),
                whiskerprops=dict(color=colors['whiskers']),
                capprops=dict(color=colors['caps']), 
                meanprops=dict(marker='^', markerfacecolor='green', markeredgecolor='green')
                )

plt.tight_layout()
plt.subplots_adjust(wspace=0.15)
plt.show()

# %% [markdown]
# What was the IQR of the control group before the newsfeed?

# %%
ans = -20 - -170
print(ans)
# Out:
# 150
