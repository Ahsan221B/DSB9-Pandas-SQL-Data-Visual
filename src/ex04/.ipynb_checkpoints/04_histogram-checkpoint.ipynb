# %%
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt

# %%
db_file = "../data/checking-logs.sqlite"
conn = sqlite3.connect(db_file)

# %%
query = """
SELECT 
    CASE
        WHEN CAST(strftime('%w', timestamp) AS INTEGER) BETWEEN 1 AND 5 THEN 'working_day'
        ELSE 'weekend'
    END AS day,
    strftime('%H', timestamp) AS hour,
    COUNT(*) as commits
FROM checker
WHERE uid LIKE 'user_%'
GROUP BY
    CASE
        WHEN CAST(strftime('%w', timestamp) AS INTEGER) BETWEEN 1 AND 5 THEN 'working_day'
        ELSE 'weekend'
    END,
    strftime('%H', timestamp);
"""


commits_df = pd.read_sql(query, conn)
commits_df
# Out:
#             day hour  commits
# 0       weekend   00        6
# 1       weekend   01        6
# 2       weekend   03        1
# 3       weekend   05        2
# 4       weekend   07       16
# 5       weekend   08       28
# 6       weekend   09       22
# 7       weekend   10       28
# 8       weekend   11      118
# 9       weekend   12       57
# 10      weekend   13      108
# 11      weekend   14       87
# 12      weekend   15      114
# 13      weekend   16       74
# 14      weekend   17       50
# 15      weekend   18       68
# 16      weekend   19      105
# 17      weekend   20      117
# 18      weekend   21       72
# 19      weekend   22       59
# 20      weekend   23       32
# 21  working_day   00        6
# 22  working_day   03        2
# 23  working_day   05       15
# 24  working_day   06        3
# 25  working_day   07       31
# 26  working_day   08       37
# 27  working_day   09       30
# 28  working_day   10      132
# 29  working_day   11       88
# ...

# %%
weekend = commits_df[commits_df['day'] == 'weekend']
working = commits_df[commits_df['day'] == 'working_day']

plt.figure(figsize=(15, 8))

plt.hist(working['hour'].astype(int), bins=range(25), 
         weights=working['commits'], label='working days', color='cyan')

plt.hist(weekend['hour'].astype(int), bins=range(25), 
         weights=weekend['commits'], alpha=0.7, label='weekend', color='red')

plt.xlim(0, 25)
plt.ylim(bottom=0)
plt.xlabel('Hour of day')
plt.ylabel('Number of commits')
plt.title('Commit frequency by hour')
plt.legend()
plt.show()

# %%
conn.close()

# %% [markdown]
# Are there hours when the total number of commits was higher on weekends than on working days?

# %% [markdown]
# 11, 13, 22, 23
