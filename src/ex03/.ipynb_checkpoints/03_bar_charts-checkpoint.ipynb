# %%
import pandas as pd
import sqlite3

# %%
db_file = "../data/checking-logs.sqlite"
conn = sqlite3.connect(db_file)

# %% [markdown]
# For each hour, calculate the average number of commits on working days and weekends. If there were no commits in an hour, do not use it to calculate the average. Use these values for your graph. For example: Monday, 17–18: 5 commits; Tuesday, 17–18: 6 commits; Wednesday, 17–18: 7 commits.

# %%
query = """
SELECT 
    CASE
        WHEN CAST(strftime('%w', timestamp) AS INTEGER) BETWEEN 1 AND 5 THEN 'working_day'
        ELSE 'weekend'
    END AS day,
    strftime('%H', timestamp) AS hour,
    DATE(timestamp) AS date,
    COUNT(*) as commits
FROM checker
WHERE uid LIKE 'user_%'
GROUP BY
    CASE
        WHEN CAST(strftime('%w', timestamp) AS INTEGER) BETWEEN 1 AND 5 THEN 'working_day'
        ELSE 'weekend'
    END,
    strftime('%H', timestamp),
    DATE(timestamp);
"""


commits_df = pd.read_sql(query, conn)
print(commits_df)
# Out:
#              day hour        date  commits
# 0        weekend   00  2020-04-19        2
# 1        weekend   00  2020-04-26        2
# 2        weekend   00  2020-05-10        2
# 3        weekend   01  2020-05-10        6
# 4        weekend   03  2020-04-25        1
# ..           ...  ...         ...      ...
# 283  working_day   22  2020-05-14        8
# 284  working_day   22  2020-05-20        4
# 285  working_day   23  2020-05-11        4
# 286  working_day   23  2020-05-13        8
# 287  working_day   23  2020-05-20        3
#
# [288 rows x 4 columns]

# %%
commits_df = commits_df.groupby(['day', 'hour'])['commits'].mean().reset_index()
commits_df
# Out:
#             day hour    commits
# 0       weekend   00   2.000000
# 1       weekend   01   6.000000
# 2       weekend   03   1.000000
# 3       weekend   05   2.000000
# 4       weekend   07   4.000000
# 5       weekend   08   7.000000
# 6       weekend   09   3.666667
# 7       weekend   10   7.000000
# 8       weekend   11  23.600000
# 9       weekend   12   9.500000
# 10      weekend   13  18.000000
# 11      weekend   14  12.428571
# 12      weekend   15  14.250000
# 13      weekend   16  14.800000
# 14      weekend   17   7.142857
# 15      weekend   18   9.714286
# 16      weekend   19  13.125000
# 17      weekend   20  13.000000
# 18      weekend   21  10.285714
# 19      weekend   22   9.833333
# 20      weekend   23   6.400000
# 21  working_day   00   3.000000
# 22  working_day   03   2.000000
# 23  working_day   05   7.500000
# 24  working_day   06   1.500000
# 25  working_day   07   5.166667
# 26  working_day   08   3.700000
# 27  working_day   09   6.000000
# ...

# %%
commits_df['hour'] = commits_df['hour'].astype(int)

# %%
commits_df = commits_df.pivot(index='hour', columns='day', values='commits')
commits_df
# Out:
# day     weekend  working_day
# hour
# 0      2.000000     3.000000
# 1      6.000000          NaN
# 3      1.000000     2.000000
# 5      2.000000     7.500000
# 6           NaN     1.500000
# 7      4.000000     5.166667
# 8      7.000000     3.700000
# 9      3.666667     6.000000
# 10     7.000000    13.200000
# 11    23.600000     6.769231
# 12     9.500000     7.181818
# 13    18.000000     8.111111
# 14    12.428571    10.166667
# 15    14.250000    12.818182
# 16    14.800000    18.888889
# 17     7.142857    16.000000
# 18     9.714286    15.181818
# 19    13.125000    17.833333
# 20    13.000000    14.076923
# 21    10.285714    24.333333
# 22     9.833333     3.750000
# 23     6.400000     5.000000

# %%
commits_df = commits_df.reindex(range(24)).fillna(0)
commits_df
# Out:
# day     weekend  working_day
# hour
# 0      2.000000     3.000000
# 1      6.000000     0.000000
# 2      0.000000     0.000000
# 3      1.000000     2.000000
# 4      0.000000     0.000000
# 5      2.000000     7.500000
# 6      0.000000     1.500000
# 7      4.000000     5.166667
# 8      7.000000     3.700000
# 9      3.666667     6.000000
# 10     7.000000    13.200000
# 11    23.600000     6.769231
# 12     9.500000     7.181818
# 13    18.000000     8.111111
# 14    12.428571    10.166667
# 15    14.250000    12.818182
# 16    14.800000    18.888889
# 17     7.142857    16.000000
# 18     9.714286    15.181818
# 19    13.125000    17.833333
# 20    13.000000    14.076923
# 21    10.285714    24.333333
# 22     9.833333     3.750000
# 23     6.400000     5.000000

# %%
commits_df.plot(
    kind='bar',
    subplots=True,
    figsize=(15,8),
    sharex=True,
    rot=True,
    yticks=range(0, 30, 5), 
    color=['purple', 'green']
)
# Out:
# array([<Axes: title={'center': 'weekend'}, xlabel='hour'>,
#        <Axes: title={'center': 'working_day'}, xlabel='hour'>],
#       dtype=object)

# %% [markdown]
# Is the dynamic different on working days and weekends?
# Yes. Working Days = 21:00, Weekend = 11:00

# %%
conn.close()
